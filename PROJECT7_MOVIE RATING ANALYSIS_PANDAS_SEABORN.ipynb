# %% [markdown]
# # ADVANCED VISUALISATION OF MOVIE RATING DATASET

# %% [markdown]
# PROJECT-7 : MOVIE RATING ANALYSIS WITH PANDA,SEABORN,USECASE, PROBLEM STAMENT, SOLUTION

# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\nithi\\data_science_projects'

# %%
import numpy
print(numpy.__version__)
# Out:
# 1.24.3

# %%
movies = pd.read_csv(r'C:\Users\nithi\OneDrive\Desktop\full stack data science & ai with chatgpt\JULY\25th\25th\25th\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\Movie-Rating.csv')

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions', 'Year']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre.index
# Out:
# RangeIndex(start=0, stop=559, step=1)

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
# how to work with joint plots

from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Joint plot is similar to scatterplot and find relation between  critic Rating & Audience Rating

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating')

#audience Rating is more than critic rating
#based on this , audiences prefer to watch movies based on audience rating than critic rating 
#critic rating is uniform and audience rating is normal distributiob

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating', kind='hex')
#kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }
    #Kind of plot to draw. See the examples for references to the underlying functions.

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating', kind='reg')

# %%
j = sns.jointplot(data=movies, x ='CriticRating', y='AudienceRating', kind='scatter')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y='AudienceRating', kind='kde')

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating', kind='hist', color='g')

# %%
#Draw a plot of two variables with bivariate and univariate graphs.

# %%
#Histograms

m1 = sns.distplot(movies.AudienceRating)

#y axis generates density automatically that is provided by seaborn gallery

# %%
sns.set_style('darkgrid')
#style : dict, or one of {darkgrid, whitegrid, dark, white, ticks}

# %%
m2 = sns.distplot(movies.AudienceRating, bins=15)

# %%
n1 = plt.hist(movies.AudienceRating, bins = 15)

# %%
#normal distribution & bell curve & 0 skewness of AudienceRating
sns.set_style('whitegrid')
n2 = plt.hist(movies.AudienceRating, bins=15)

# %%
n1 = plt.hist(movies.CriticRating, bins = 15)  #uniform distribution

# %% [markdown]
# Staked Histograms

# %%
plt.hist(movies.BudgetMillions)
plt.xlabel('BudgetMillions')
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
#below plots are stacked histogram bcoz overlaped

plt.hist(movies[movies.Genre=='Action'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genre=='Thriller'].BudgetMillions, bins=20)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,\
        movies[movies.Genre=='Drama'].BudgetMillions,\
        movies[movies.Genre=='Thriller'].BudgetMillions,\
        movies[movies.Genre=='Comedy'].BudgetMillions],
         bins=20, stacked = True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
#Bi variate analysis
sns.set_style('white')
vis1 = sns.lmplot(data = movies, x='CriticRating', y='AudienceRating',\
                  fit_reg=False)

# %%
vis1 = sns.lmplot(data = movies, x='CriticRating', y='AudienceRating', fit_reg=False, hue='Genre')

# %%
vis1 = sns.lmplot(data = movies, x='CriticRating', y='AudienceRating', fit_reg=True, hue='Genre')

# %% [markdown]
# KDE PLOT: kernel density plot

# %%
k1 = sns.kdeplot(data=movies,x='CriticRating',y='AudienceRating')

#kernel is at the center and the density spreads across audience rating

#A kernel density estimate (KDE) plot is a method for visualizing the
#distribution of observations in a dataset, analogous to a histogram. KDE
#represents the data using a continuous probability density curve in one or
#more dimensions.

# %%
k1 = sns.kdeplot(data=movies,x='CriticRating',y='AudienceRating',shade = False,shade_lowest=False,cmap='Reds')

# %%
k1 = sns.kdeplot(data=movies,x='CriticRating',y='AudienceRating',shade = True,shade_lowest=False,cmap='Reds')

# %%
k1 = sns.kdeplot(data=movies,x='CriticRating',y='AudienceRating',shade = True,shade_lowest=True,cmap='Greens')

# %%
sns.set_style('dark')
k1=sns.kdeplot(data=movies,x='BudgetMillions', y='AudienceRating', shade=True,shade_lowest=False, cmap='Greens')
#low budgets movies have hig audience rating and density spreads to big budget

# %%
sns.set_style('white')
k1 = sns.kdeplot(data= movies, x='BudgetMillions', y='AudienceRating')

# %%
k2 = sns.kdeplot(data=movies, x='BudgetMillions', y='CriticRating')
#for low buget movies of btw 0 to 50 million $ density spreads through 0 to 50 million movies

# %% [markdown]
# SUBPLOTS

# %%
f, ax= plt.subplots(1,2, figsize=(10,3))

# %%
f, ax = plt.subplots(3,3, figsize=(10,5))

# %%
f, axes = plt.subplots(1,2, figsize=(12,6))

k1 = sns.kdeplot(data=movies, x='BudgetMillions',y='CriticRating',ax=axes[0])
k2 = sns.kdeplot(data=movies, x='BudgetMillions',y='AudienceRating',ax=axes[1])

# %%
axes
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='CriticRating'>,
#        <Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>],
#       dtype=object)

# %%
#BoxPlots

b= sns.boxplot(data=movies, x='Genre', y='CriticRating')

#analyse which genre has highest critic rating : Drama ,Comedy

# %%
#violin plot

v= sns.violinplot(data=movies, x='Genre', y='CriticRating')

# %%
w= sns.boxplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %%
w1= sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %% [markdown]
# FACET GRID: Multi-plot grid for plotting conditional relationships.

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue = 'Genre')  # 7rows and 5 cols

# %%
plt.scatter(movies.CriticRating, movies.AudienceRating)

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating' ) #scatterplots are mapped in facetgrid

#Apply a plotting function to each facet's subset of the data.
#consider adventure, Drama, Horror, Romance

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillions' ) #histogram are mapped in facetgrid

# %%
#**kwargs

g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws )

# %%
#Building DashBoards


sns.set_style('darkgrid')
f, axes = plt.subplots(2,2, figsize=(10,10))

k1 =sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating', ax=axes[0,0])
k2 =sns.kdeplot(data=movies, x='BudgetMillions', y='CriticRating', ax=axes[0,1])

s = sns.violinplot(data= movies[movies.Genre=='Drama'], x='Year', y='CriticRating', ax = axes[1,0])
k3 = sns.kdeplot(data = movies, x='CriticRating', y='AudienceRating', shade=True, shade_lowest= False, cmap='Reds', ax=axes[1,1])

plt.show()

# %%
# How can you style your dashboard  using different color map

# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(data=movies,x='BudgetMillions',y='AudienceRating', \
                 shade = True, shade_lowest=False,cmap = 'cool', \
                 ax = axes[0,0])
k1b = sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating', \
                 cmap = 'cool',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(data=movies,x='BudgetMillions',y='CriticRating',\
                 shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(data=movies,x='BudgetMillions',y='CriticRating',\
                  cmap = 'cool', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=movies[movies.Genre=='Drama'], \
                   x='Year', y = 'CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(data=movies, x='CriticRating',y='AudienceRating', \
                 shade = True,shade_lowest=False,cmap='Blues_r', \
                 ax=axes[1,1])

k4b = sns.kdeplot(data=movies,x='CriticRating', y='AudienceRating', \
                  cmap='gist_gray_r',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()

# %% [markdown]
# Final discussion what we learn so far -
# 1> category datatype in python
# 2> jointplots
# 3> histogram
# 4> stacked histograms
# 5> Kde plot
# 6> subplot
# 7> violin plots
# 8> Factet grid
# 9> Building dashboards

# %%
#EDA IS completed
